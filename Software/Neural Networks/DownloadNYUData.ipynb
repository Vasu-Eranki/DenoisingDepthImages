# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
ds = load_dataset("sayakpaul/nyu_depth_v2",num_proc=1)
# Out:
# ...
# Generating validation split:   0%|          | 0/654 [00:00<?, ? examples/s]

# %%
import torch

# %%
# !ls drive/MyDrive/M202A/
# Out:
# ddd  MidtermPresentation.pdf  MidtermPresentation.pptx	nyu_depth_v2_labeled.mat  transcg  Unet.pth

# %%
ds.save_to_disk("drive/MyDrive/M202A/nyu.hf");
# Out:
# ...
# Saving the dataset (0/3 shards):   0%|          | 0/654 [00:00<?, ? examples/s]
